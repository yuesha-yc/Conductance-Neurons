# %%
from plotting import *

# %%
trials = collect_data("../outputs/conductance/single_lif/nu_x_realistic_candidate3/20251012-003546-M8ObQrGX")

plot_xy(trials, param_filter={}, x="nu_x", y="fano_factor", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_V", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="var_V", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="nu", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_g_e", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_g_i", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_I_e", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_I_i", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_I_tot", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="var_I_tot", l="a")

# %%
trials = collect_data("../outputs/conductance/single_lif/nu_x_realistic_candidate4/20251014-163223-XKeYsbli")

plot_xy(trials, param_filter={}, x="nu_x", y="fano_factor", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="nu", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_V", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="var_V", l="a")
# plot_xy(trials, param_filter={}, x="nu_x", y="mean_g_e", l="a")
# plot_xy(trials, param_filter={}, x="nu_x", y="mean_g_i", l="a")
# plot_xy(trials, param_filter={}, x="nu_x", y="mean_I_e", l="a")
# plot_xy(trials, param_filter={}, x="nu_x", y="mean_I_i", l="a")
# plot_xy(trials, param_filter={}, x="nu_x", y="mean_I_tot", l="a")
# plot_xy(trials, param_filter={}, x="nu_x", y="var_I_tot", l="a")

# %%
trials = collect_data("../outputs/conductance/single_lif/nu_x_realistic_candidate4/20251014-170123-6FwYoJv6")

plot_xy(trials, param_filter={}, x="nu_x", y="fano_factor", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="nu", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_V", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="var_V", l="a")

# %%
plot_tv(trials, param_filter={"nu_x": 520}, t_key="t", v_key="V")

# %%
trials[0][1]
# Out:
# {'nu': 7.21864406779661,
#  'V': array([-62.45326526, -62.58206198, -62.69948199, ..., -66.10546402,
#         -66.07369253, -66.06170908], shape=(10000,)),
#  'fano_factor': 1.5781049730994483,
#  'mean_g_e': 1.8874872759550703,
#  'I_i': array([-131.54486957, -127.68360438, -127.37692761, ...,  -55.41335184,
#          -56.93393279,  -56.39385408], shape=(10000,)),
#  't': array([0.000e+00, 1.000e-01, 2.000e-01, ..., 9.997e+02, 9.998e+02,
#         9.999e+02], shape=(10000,)),
#  'mean_I_i': -117.98697880091893,
#  'g_e': array([1.72624513, 1.69172022, 1.65788582, ..., 0.91154574, 0.89331483,
#         0.87544853], shape=(10000,)),
#  'mean_I_tot': 15.706258294822725,
#  'var_I_tot': 966.5882059115626,
#  'var_V': 9.974072676731113,
#  'mean_V': -62.15157622898393,
#  'var_g_e': 0.826564081155518,
#  'I_e': array([125.07209597, 122.78854207, 120.52744018, ...,  69.37361164,
#          67.95775746,  66.58811142], shape=(10000,)),
# ...

# %%
V = trials[9][1]['V']
t = trials[9][1]['t']
# set fig size to be wide and short
plt.figure(figsize=(12, 2))
plt.plot(t, V)
plt.xlim(0, 1000)
plt.tight_layout()

# %%
V = trials[2][1]['V']
t = trials[2][1]['t']
# set fig size to be wide and short
plt.figure(figsize=(12, 2))
plt.plot(t, V)
plt.xlim(0, 1000)
plt.tight_layout()

# %%
trials = collect_data("../outputs/conductance/single_lif/nu_x_realistic_candidate4/20251014-174558-dAkWUKOb")

plot_xy(trials, param_filter={}, x="nu_x", y="fano_factor", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="nu", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_V", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="var_V", l="a")

# %%
trials = collect_data("../outputs/conductance/single_lif/nu_x_realistic_candidate4/20251014-183151-10rg4wln")

plot_xy(trials, param_filter={}, x="nu_x", y="fano_factor", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="nu", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_V", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="var_V", l="a")

# %%
trials = collect_data("../outputs/conductance/single_lif/nu_x_realistic_candidate4/20251014-185354-tqv7G0ep")

plot_xy(trials, param_filter={}, x="nu_x", y="fano_factor", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="nu", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="mean_V", l="a")
plot_xy(trials, param_filter={}, x="nu_x", y="var_V", l="a")
